# %% [markdown]
# # Notebook 1: Data preparation
#
# In this notebook, each file from the `/data/raw` folder will be processed using the following steps:
#
# 1. Dataframe general overview.
# 2. Column processing: drop, rename, order.
# 3. Missing data treatment.
#
# Then, if possible, datasets will be merged and saved in the `/data/processed` folder.
#
# Lastly, a dataset card with all relevant information will be created for each dataset.
#
#
# #### Table of contents:
# * [Data Cleaning](#data-cleaning)
#     * [Dataset 1](#dataset-1-alzheimers_disease_data)
#     * [Dataset 2](#dataset-2-blood_marker)
#     * [Dataset 3](#dataset-3-baseline_data)
#     * [Dataset 4](#dataset-4-adnimerge)
# * [Dataset Cards](#dataset-cards)
#     * [Main data](#dataset-main_data)
#     * [Biomarker data](#dataset-biomarker_data)
#     * [ADNI data](#dataset-adni_data)

# %% [markdown]
# ## Imports

# %%
import os
import re
import sys
import pandas as pd

pd.options.display.max_columns = None

# %%
# Gets src path 
src_path = os.path.dirname(os.getcwd())

# Adds src_path if it doesn't exist in sys.path (to access utils)
if os.path.exists(src_path) and src_path not in sys.path:
    sys.path.append(src_path)
    
from utils.data_tools import classify_by_cardinality

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# ### Dataset 1: alzheimers_disease_data

# %%
# General overview

df_ad = pd.read_csv('../data/raw/alzheimers_disease_data.csv')
df_ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2149 entries, 0 to 2148
# Data columns (total 35 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   PatientID                  2149 non-null   int64
#  1   Age                        2149 non-null   int64
#  2   Gender                     2149 non-null   int64
#  3   Ethnicity                  2149 non-null   int64
#  4   EducationLevel             2149 non-null   int64
#  5   BMI                        2149 non-null   float64
#  6   Smoking                    2149 non-null   int64
#  7   AlcoholConsumption         2149 non-null   float64
#  8   PhysicalActivity           2149 non-null   float64
#  9   DietQuality                2149 non-null   float64
#  10  SleepQuality               2149 non-null   float64
#  11  FamilyHistoryAlzheimers    2149 non-null   int64
#  12  CardiovascularDisease      2149 non-null   int64
#  13  Diabetes                   2149 non-null   int64
#  14  Depression                 2149 non-null   int64
#  15  HeadInjury                 2149 non-null   int64
#  16  Hypertension               2149 non-null   int64
#  17  SystolicBP                 2149 non-null   int64
#  18  DiastolicBP                2149 non-null   int64
#  19  CholesterolTotal           2149 non-null   float64
#  20  CholesterolLDL             2149 non-null   float64
#  21  CholesterolHDL             2149 non-null   float64
#  22  CholesterolTriglycerides   2149 non-null   float64
#  23  MMSE                       2149 non-null   float64
#  24  FunctionalAssessment       2149 non-null   float64
#  25  MemoryComplaints           2149 non-null   int64
#  26  BehavioralProblems         2149 non-null   int64
#  27  ADL                        2149 non-null   float64
#  28  Confusion                  2149 non-null   int64
#  29  Disorientation             2149 non-null   int64
#  30  PersonalityChanges         2149 non-null   int64
#  31  DifficultyCompletingTasks  2149 non-null   int64
#  32  Forgetfulness              2149 non-null   int64
#  33  Diagnosis                  2149 non-null   int64
#  34  DoctorInCharge             2149 non-null   object
# dtypes: float64(12), int64(22), object(1)
# memory usage: 587.7+ KB

# %%
# Column processing

# Column selection
df_ad.drop(columns = ['DoctorInCharge'], inplace = True)

# Transform categoric data in numeric format to string format
ethnicity = ['Caucasian', 'African American', 'Asian', 'Other']
education = ['None', 'High School', 'Bachelors', 'Higher']

df_ad['Ethnicity'] = df_ad['Ethnicity'].apply(lambda x: ethnicity[x])
df_ad['EducationLevel'] = df_ad['EducationLevel'].apply(lambda x: education[x])

# Rename columns
add_ = lambda s: re.sub(r'(?<=[a-z])([A-Z])', r'_\1', s)
df_ad.columns = [add_(col) for col in df_ad.columns]

new_col_ad = {
    'Education_Level': 'Education_lv',
    'Cardiovascular_Disease': 'CVD',
    'Diagnosis': 'DX'
}
df_ad.rename(columns = new_col_ad, inplace = True)

# Transform Patient_ID to identify source dataset
df_ad['Patient_ID'] = df_ad['Patient_ID'].apply(lambda x: f'm_{x}')

# %%
df_ad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2149 entries, 0 to 2148
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Patient_ID                   2149 non-null   object
#  1   Age                          2149 non-null   int64
#  2   Gender                       2149 non-null   int64
#  3   Ethnicity                    2149 non-null   object
#  4   Education_lv                 2149 non-null   object
#  5   BMI                          2149 non-null   float64
#  6   Smoking                      2149 non-null   int64
#  7   Alcohol_Consumption          2149 non-null   float64
#  8   Physical_Activity            2149 non-null   float64
#  9   Diet_Quality                 2149 non-null   float64
#  10  Sleep_Quality                2149 non-null   float64
#  11  Family_History_Alzheimers    2149 non-null   int64
#  12  CVD                          2149 non-null   int64
#  13  Diabetes                     2149 non-null   int64
#  14  Depression                   2149 non-null   int64
#  15  Head_Injury                  2149 non-null   int64
#  16  Hypertension                 2149 non-null   int64
#  17  Systolic_BP                  2149 non-null   int64
#  18  Diastolic_BP                 2149 non-null   int64
#  19  Cholesterol_Total            2149 non-null   float64
#  20  Cholesterol_LDL              2149 non-null   float64
#  21  Cholesterol_HDL              2149 non-null   float64
#  22  Cholesterol_Triglycerides    2149 non-null   float64
#  23  MMSE                         2149 non-null   float64
#  24  Functional_Assessment        2149 non-null   float64
#  25  Memory_Complaints            2149 non-null   int64
#  26  Behavioral_Problems          2149 non-null   int64
#  27  ADL                          2149 non-null   float64
#  28  Confusion                    2149 non-null   int64
#  29  Disorientation               2149 non-null   int64
#  30  Personality_Changes          2149 non-null   int64
#  31  Difficulty_Completing_Tasks  2149 non-null   int64
#  32  Forgetfulness                2149 non-null   int64
#  33  DX                           2149 non-null   int64
# dtypes: float64(12), int64(19), object(3)
# memory usage: 571.0+ KB

# %%
# Save clean dataset

df_ad.to_csv('../data/processed/main_data.csv', index = False)

# %% [markdown]
# ### Dataset 2: blood_marker

# %%
# General overview

df_biomarker = pd.read_excel('../data/raw/blood_marker.xlsx')
df_biomarker.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113 entries, 0 to 112
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Name number                  113 non-null    object
#  1   sex                          113 non-null    object
#  2   age                          113 non-null    int64
#  3   Height/meter                 113 non-null    float64
#  4   weight                       113 non-null    float64
#  5   BMI                          113 non-null    float64
#  6   education years              113 non-null    int64
#  7   smoking 1=yes 0=no           113 non-null    int64
#  8   Drinking 1=yes 0=no          113 non-null    int64
#  9   Hypertension 1=yes 0=no      113 non-null    int64
#  10  Coronary disease 1=yes 0=no  113 non-null    int64
#  11  Diabetes 1=yes 0=no          113 non-null    int64
#  12  MMSE Score                   113 non-null    int64
#  13  MoCA Score                   113 non-null    int64
#  14  Plasma GFAP                  113 non-null    float64
#  15  Plasma NfL                   113 non-null    float64
#  16  Plasma p-tau181              113 non-null    float64
# dtypes: float64(6), int64(9), object(2)
# memory usage: 15.1+ KB

# %%
# Column processing

# Column selection
df_biomarker.drop(columns = ['Height/meter', 'weight'], inplace = True)

# Change 'sex' column type to binary
df_biomarker['sex'] = df_biomarker['sex'].apply(lambda x: 1 if x == 'female' else 0)

# Insert column for main diagnosis
df_biomarker.insert(12, 'DX', df_biomarker['Name number'].apply(lambda x: re.sub('[0-9]', '', x).strip()) ,allow_duplicates = True)

# Rename columns to match main_data
new_col_biomarker = {
    'Name number': 'Patient_ID',
    'sex': 'Gender',
    'age': 'Age',
    'education years': 'Education_yrs',
    'smoking 1=yes 0=no': 'Smoking',
    'Drinking 1=yes 0=no': 'Drinking',
    'Hypertension 1=yes 0=no': 'Hypertension',
    'Coronary disease 1=yes 0=no': 'CVD',
    'Diabetes 1=yes 0=no': 'Diabetes',
    'MMSE Score': 'MMSE',
    'MoCA Score': 'MOCA',
    'Plasma GFAP': 'Plasma_GFAP',
    'Plasma NfL': 'Plasma_NfL',
    'Plasma p-tau181': 'Plasma_ptau181'
}
df_biomarker.rename(columns = new_col_biomarker, inplace = True)

# Transform Patient_ID to identify source dataset
df_biomarker['Patient_ID'] = df_biomarker['Patient_ID'].apply(lambda x: f'bm_{x}')

# %%
df_biomarker
# Out:
#     Patient_ID  Gender  Age        BMI  Education_yrs  Smoking  Drinking  \
# 0       bm_CU1       1   71  22.656250             10        0         0
# 1       bm_CU2       0   61  22.093170             14        1         1
# 2       bm_CU3       0   55  25.734393             10        1         1
# 3       bm_CU4       1   53  19.879103             10        0         0
# 4       bm_CU5       0   74  25.711662              7        1         0
# ..         ...     ...  ...        ...            ...      ...       ...
# 108    bm_AD11       1   77  19.531250              8        0         0
# 109    bm_AD12       1   75  24.444444             12        0         0
# 110    bm_AD13       0   81  22.491349             16        1         1
# 111    bm_AD14       0   90  20.399714             16        1         1
# 112    bm_AD15       0   89  18.518519             12        1         1
#
#      Hypertension  CVD  Diabetes  MMSE  MOCA  DX  Plasma_GFAP  Plasma_NfL  \
# 0               1    0         1    28    23  CU   187.788983   44.382631
# 1               1    0         0    30    30  CU   129.526091   13.127498
# 2               0    0         0    29    27  CU    57.363792   10.554058
# 3               0    0         0    30    28  CU    88.835118   16.894295
# 4               1    0         1    30    27  CU   160.402572   25.697172
# ..            ...  ...       ...   ...   ...  ..          ...         ...
# 108             0    0         1    12    10  AD   158.630000   58.310000
# 109             0    0         0    24    20  AD   180.050000   23.010000
# 110             0    0         0    22    15  AD   295.310000   69.180000
# 111             1    0         1    22    18  AD   377.460000   54.290000
# 112             1    0         0     2     2  AD   207.990000   50.000000
#
#      Plasma_ptau181
# 0          3.530901
# 1          2.684318
# 2          2.670783
# 3          1.310089
# 4          3.562334
# ..              ...
# 108        2.830000
# 109        2.210000
# 110        3.490000
# 111        3.040000
# 112        6.120000
#
# [113 rows x 16 columns]

# %%
# Save clean dataset

df_biomarker.to_csv('../data/processed/biomarker_data.csv', index = False)

# %% [markdown]
# ### Dataset 3: baseline_data

# %%
# General overview

df_bl = pd.read_csv('../data/raw/baseline_data.csv', index_col = 0)
df_bl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 767 entries, 1 to 3129
# Data columns (total 57 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   RID                 767 non-null    int64
#  1   VISCODE             767 non-null    object
#  2   time                767 non-null    int64
#  3   BLPLASMA            767 non-null    float64
#  4   DXCHANGE            767 non-null    int64
#  5   GROUP_abeta         767 non-null    object
#  6   DX                  767 non-null    int64
#  7   AGE                 767 non-null    float64
#  8   PTGENDER            767 non-null    int64
#  9   PTEDUCAT            767 non-null    int64
#  10  APOE4               767 non-null    int64
#  11  GROUP               767 non-null    object
#  12  DX_bl               767 non-null    object
#  13  DXX                 767 non-null    object
#  14  EXAMDATE.key        767 non-null    object
#  15  PLASMAPTAU181       767 non-null    float64
#  16  FDG                 762 non-null    float64
#  17  AV45                761 non-null    float64
#  18  ABETA42             704 non-null    float64
#  19  TAU                 704 non-null    float64
#  20  PTAU                703 non-null    float64
#  21  TAUAB               704 non-null    float64
#  22  PTAUAB              703 non-null    float64
#  23  MMSE                767 non-null    int64
#  24  MOCA                757 non-null    float64
#  25  ADNI_MEM            767 non-null    float64
#  26  ADNI_EF             767 non-null    float64
#  27  ADNI_LAN            767 non-null    float64
#  28  ADNI_VS             767 non-null    float64
#  29  TOTAL_HIPPO         766 non-null    float64
#  30  TOTAL_WMH           766 non-null    float64
#  31  TOTAL_BRAIN         766 non-null    float64
#  32  INFARCT             698 non-null    float64
#  33  CVD                 645 non-null    float64
#  34  Cancer              645 non-null    float64
#  35  Current.Depression  645 non-null    float64
#  36  DM2                 645 non-null    float64
#  37  Hypertension        645 non-null    float64
#  38  lipid               645 non-null    float64
#  39  smoking             645 non-null    float64
#  40  stroke              645 non-null    float64
#  41  BLFDG               763 non-null    float64
#  42  BLAV45              762 non-null    float64
#  43  BLABETA42           704 non-null    float64
#  44  BLTAU               704 non-null    float64
#  45  BLPTAU              703 non-null    float64
#  46  BLTAUAB             704 non-null    float64
#  47  BLPTAUAB            703 non-null    float64
#  48  BLMMSE              767 non-null    int64
#  49  BLMOCA              757 non-null    float64
#  50  BLMEM               767 non-null    float64
#  51  BLEF                767 non-null    float64
#  52  BLLAN               767 non-null    float64
#  53  BLVS                767 non-null    float64
#  54  BLHIPPO             766 non-null    float64
#  55  BLWMH               766 non-null    float64
#  56  BLBRAIN             766 non-null    float64
# dtypes: float64(42), int64(9), object(6)
# memory usage: 347.5+ KB

# %%
# Column processing

# Column selection
keep_col = ['RID', 'AGE', 'PTGENDER', 'PTEDUCAT', 'smoking', 'CVD', 'DM2', 'Current.Depression', 'Hypertension', 'stroke', 'MMSE', 'MOCA', 'APOE4', 'GROUP', 'DXX', 'PLASMAPTAU181']
df_bl = df_bl[keep_col]

# Transform GROUP codification
group_dict = {
    'A': 'CU-',
    'B': 'CU+',
    'C': 'MCI+',
    'DF': 'AD',
    'E': 'MCI-'
}
df_bl['GROUP'] = df_bl['GROUP'].apply(lambda x: group_dict[x])

# Update DXX codification
df_bl['DXX'] = df_bl['DXX'].apply(lambda x: 'CU' if x == 'CN' else x)

# Rename columns to match main_data
df_bl.columns = [col.lower().capitalize() if col not in ['RID', 'CVD', 'MMSE', 'MOCA', 'APOE4'] else col for col in df_bl.columns]
new_col_bl = {
    'Ptgender': 'Gender',
    'Pteducat': 'Education_yrs',
    'Dm2': 'Diabetes',
    'Current.depression': 'Depression',
    'Dxx': 'DX',
    'Plasmaptau181': 'Plasma_ptau181'
}
df_bl.rename(columns = new_col_bl, inplace = True)

# Sort values by 'RID'
df_bl = df_bl.sort_values(by = 'RID')

# %%
df_bl
# Out:
#        RID   Age  Gender  Education_yrs  Smoking  CVD  Diabetes  Depression  \
# 1     2002  64.8       0             16      1.0  1.0       0.0         0.0
# 7     2007  83.4       1             20      0.0  0.0       1.0         0.0
# 12    2010  62.9       1             20      NaN  NaN       NaN         NaN
# 17    2018  76.4       1             18      0.0  1.0       0.0         0.0
# 21    2022  66.0       0             18      0.0  1.0       0.0         0.0
# ...    ...   ...     ...            ...      ...  ...       ...         ...
# 3116  5289  59.7       1             16      NaN  NaN       NaN         NaN
# 3120  5290  67.0       1             12      0.0  1.0       0.0         1.0
# 3123  5292  74.3       1             13      0.0  0.0       0.0         1.0
# 3127  5295  75.5       1             15      NaN  NaN       NaN         NaN
# 3129  5296  69.3       0             14      0.0  1.0       0.0         0.0
#
#       Hypertension  Stroke  MMSE  MOCA  APOE4 Group   DX  Plasma_ptau181
# 1              0.0     0.0    28  28.0      0  MCI-  MCI           6.777
# 7              1.0     0.0    29  23.0      0  MCI+  MCI          37.897
# 12             NaN     NaN    30  27.0      1  MCI+  MCI          23.263
# 17             1.0     0.0    29  26.0      0  MCI-  MCI          10.252
# 21             1.0     0.0    29  25.0      1  MCI+  MCI          16.576
# ...            ...     ...   ...   ...    ...   ...  ...             ...
# 3116           NaN     NaN    29  27.0      1   CU-   CU           8.672
# 3120           1.0     0.0    29  25.0      1   CU-   CU          18.583
# 3123           0.0     0.0    30  29.0      0   CU-   CU          17.408
# 3127           NaN     NaN    29  27.0      1   CU-   CU          10.932
# 3129           0.0     0.0    29  26.0      0   CU-   CU           4.045
#
# [767 rows x 16 columns]

# %% [markdown]
# ### Dataset 4: ADNIMERGE

# %%
# General overview

df_adni = pd.read_csv('../data/raw/ADNIMERGE.csv', low_memory = False)
print(df_adni.info())
df_adni.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14878 entries, 0 to 14877
# Columns: 113 entries, RID to update_stamp
# dtypes: float64(87), int64(5), object(21)
# memory usage: 12.8+ MB
# None
#    RID        PTID VISCODE  SITE COLPROT ORIGPROT    EXAMDATE DX_bl   AGE  \
# 0    2  011_S_0002      bl    11   ADNI1    ADNI1  2005-09-08    CN  74.3
# 1    3  011_S_0003      bl    11   ADNI1    ADNI1  2005-09-12    AD  81.3
# 2    3  011_S_0003     m06    11   ADNI1    ADNI1  2006-03-13    AD  81.3
# 3    3  011_S_0003     m12    11   ADNI1    ADNI1  2006-09-12    AD  81.3
# 4    3  011_S_0003     m24    11   ADNI1    ADNI1  2007-09-12    AD  81.3
#
#   PTGENDER  PTEDUCAT         PTETHCAT PTRACCAT  PTMARRY  APOE4      FDG  PIB  \
# 0     Male        16  Not Hisp/Latino    White  Married    0.0  1.36665  NaN
# 1     Male        18  Not Hisp/Latino    White  Married    1.0  1.08355  NaN
# 2     Male        18  Not Hisp/Latino    White  Married    1.0  1.05803  NaN
# 3     Male        18  Not Hisp/Latino    White  Married    1.0  1.09690  NaN
# 4     Male        18  Not Hisp/Latino    White  Married    1.0  1.03258  NaN
#
#    AV45  ABETA    TAU   PTAU  CDRSB  ADAS11  ADAS13  ADASQ4  MMSE  \
# 0   NaN    NaN    NaN    NaN    0.0   10.67   18.67     5.0  28.0
# 1   NaN  741.5  239.7  22.83    4.5   22.00   31.00     8.0  20.0
# 2   NaN    NaN    NaN    NaN    6.0   19.00   30.00    10.0  24.0
# 3   NaN  601.4  251.7  24.18    3.5   24.00   35.00    10.0  17.0
# 4   NaN    NaN    NaN    NaN    8.0   25.67   37.67    10.0  19.0
#
#    RAVLT_immediate  RAVLT_learning  RAVLT_forgetting  RAVLT_perc_forgetting  \
# 0             44.0             4.0               6.0                54.5455
# 1             22.0             1.0               4.0               100.0000
# 2             19.0             2.0               6.0               100.0000
# 3             31.0             2.0               7.0               100.0000
# 4             23.0             1.0               5.0               100.0000
#
#    LDELTOTAL  DIGITSCOR  TRABSCOR   FAQ  MOCA  EcogPtMem  EcogPtLang  \
# 0       10.0       34.0     112.0   0.0   NaN        NaN         NaN
# 1        2.0       25.0     148.0  10.0   NaN        NaN         NaN
# 2        NaN       19.0     135.0  12.0   NaN        NaN         NaN
# 3        0.0       21.0     126.0  17.0   NaN        NaN         NaN
# 4        0.0       16.0     275.0  14.0   NaN        NaN         NaN
#
#    EcogPtVisspat  EcogPtPlan  EcogPtOrgan  EcogPtDivatt  EcogPtTotal  \
# 0            NaN         NaN          NaN           NaN          NaN
# 1            NaN         NaN          NaN           NaN          NaN
# 2            NaN         NaN          NaN           NaN          NaN
# 3            NaN         NaN          NaN           NaN          NaN
# 4            NaN         NaN          NaN           NaN          NaN
#
#    EcogSPMem  EcogSPLang  EcogSPVisspat  EcogSPPlan  EcogSPOrgan  \
# 0        NaN         NaN            NaN         NaN          NaN
# 1        NaN         NaN            NaN         NaN          NaN
# 2        NaN         NaN            NaN         NaN          NaN
# 3        NaN         NaN            NaN         NaN          NaN
# 4        NaN         NaN            NaN         NaN          NaN
#
#    EcogSPDivatt  EcogSPTotal  FLDSTRENG  \
# 0           NaN          NaN        NaN
# 1           NaN          NaN        NaN
# 2           NaN          NaN        NaN
# 3           NaN          NaN        NaN
# 4           NaN          NaN        NaN
#
#                                            FSVERSION  IMAGEUID  Ventricles  \
# 0  Cross-Sectional FreeSurfer (FreeSurfer Version...   35475.0    118233.0
# 1  Cross-Sectional FreeSurfer (FreeSurfer Version...   32237.0     84599.0
# 2  Cross-Sectional FreeSurfer (FreeSurfer Version...   31863.0     88580.0
# 3  Cross-Sectional FreeSurfer (FreeSurfer Version...   35576.0     90099.0
# 4  Cross-Sectional FreeSurfer (FreeSurfer Version...   88252.0     97420.0
#
#    Hippocampus  WholeBrain  Entorhinal  Fusiform  MidTemp        ICV  \
# 0       8336.0   1229740.0      4177.0   16559.0  27936.0  1984660.0
# 1       5319.0   1129830.0      1791.0   15506.0  18422.0  1920690.0
# 2       5446.0   1100060.0      2427.0   14400.0  16972.0  1906430.0
# 3       5157.0   1095640.0      1596.0   14617.0  17330.0  1903820.0
# 4       5139.0   1088560.0      1175.0   14033.0  16398.0  1903420.0
#
#          DX  mPACCdigit  mPACCtrailsB EXAMDATE_bl  CDRSB_bl  ADAS11_bl  \
# 0        CN    -4.41296      -4.23701  2005-09-08       0.0      10.67
# 1  Dementia   -16.62830     -16.23600  2005-09-12       4.5      22.00
# 2  Dementia   -15.09690     -13.49650  2005-09-12       4.5      22.00
# 3  Dementia   -21.46350     -20.29440  2005-09-12       4.5      22.00
# 4  Dementia   -20.13660     -20.34610  2005-09-12       4.5      22.00
#
#    ADAS13_bl  ADASQ4_bl  MMSE_bl  RAVLT_immediate_bl  RAVLT_learning_bl  \
# 0      18.67        5.0       28                44.0                4.0
# 1      31.00        8.0       20                22.0                1.0
# 2      31.00        8.0       20                22.0                1.0
# 3      31.00        8.0       20                22.0                1.0
# 4      31.00        8.0       20                22.0                1.0
#
#    RAVLT_forgetting_bl  RAVLT_perc_forgetting_bl  LDELTOTAL_BL  DIGITSCOR_bl  \
# 0                  6.0                   54.5455          10.0          34.0
# 1                  4.0                  100.0000           2.0          25.0
# 2                  4.0                  100.0000           2.0          25.0
# 3                  4.0                  100.0000           2.0          25.0
# 4                  4.0                  100.0000           2.0          25.0
#
#    TRABSCOR_bl  FAQ_bl  mPACCdigit_bl  mPACCtrailsB_bl  FLDSTRENG_bl  \
# 0        112.0     0.0       -4.41296         -4.23701           NaN
# 1        148.0    10.0      -16.62830        -16.23600           NaN
# 2        148.0    10.0      -16.62830        -16.23600           NaN
# 3        148.0    10.0      -16.62830        -16.23600           NaN
# 4        148.0    10.0      -16.62830        -16.23600           NaN
#
#                                         FSVERSION_bl  Ventricles_bl  \
# 0  Cross-Sectional FreeSurfer (FreeSurfer Version...       118233.0
# 1  Cross-Sectional FreeSurfer (FreeSurfer Version...        84599.0
# 2  Cross-Sectional FreeSurfer (FreeSurfer Version...        84599.0
# 3  Cross-Sectional FreeSurfer (FreeSurfer Version...        84599.0
# 4  Cross-Sectional FreeSurfer (FreeSurfer Version...        84599.0
#
#    Hippocampus_bl  WholeBrain_bl  Entorhinal_bl  Fusiform_bl  MidTemp_bl  \
# 0          8336.0      1229740.0         4177.0      16559.0     27936.0
# 1          5319.0      1129830.0         1791.0      15506.0     18422.0
# 2          5319.0      1129830.0         1791.0      15506.0     18422.0
# 3          5319.0      1129830.0         1791.0      15506.0     18422.0
# 4          5319.0      1129830.0         1791.0      15506.0     18422.0
#
#       ICV_bl  MOCA_bl  EcogPtMem_bl  EcogPtLang_bl  EcogPtVisspat_bl  \
# 0  1984660.0      NaN           NaN            NaN               NaN
# 1  1920690.0      NaN           NaN            NaN               NaN
# 2  1920690.0      NaN           NaN            NaN               NaN
# 3  1920690.0      NaN           NaN            NaN               NaN
# 4  1920690.0      NaN           NaN            NaN               NaN
#
#    EcogPtPlan_bl  EcogPtOrgan_bl  EcogPtDivatt_bl  EcogPtTotal_bl  \
# 0            NaN             NaN              NaN             NaN
# 1            NaN             NaN              NaN             NaN
# 2            NaN             NaN              NaN             NaN
# 3            NaN             NaN              NaN             NaN
# 4            NaN             NaN              NaN             NaN
#
#    EcogSPMem_bl  EcogSPLang_bl  EcogSPVisspat_bl  EcogSPPlan_bl  \
# 0           NaN            NaN               NaN            NaN
# 1           NaN            NaN               NaN            NaN
# 2           NaN            NaN               NaN            NaN
# 3           NaN            NaN               NaN            NaN
# 4           NaN            NaN               NaN            NaN
#
#    EcogSPOrgan_bl  EcogSPDivatt_bl  EcogSPTotal_bl ABETA_bl TAU_bl PTAU_bl  \
# 0             NaN              NaN             NaN      NaN    NaN     NaN
# 1             NaN              NaN             NaN    741.5  239.7   22.83
# 2             NaN              NaN             NaN    741.5  239.7   22.83
# 3             NaN              NaN             NaN    741.5  239.7   22.83
# 4             NaN              NaN             NaN    741.5  239.7   22.83
#
#     FDG_bl  PIB_bl  AV45_bl  Years_bl  Month_bl  Month     M  \
# 0  1.36665     NaN      NaN  0.000000   0.00000      0   0.0
# 1  1.08355     NaN      NaN  0.000000   0.00000      0   0.0
# 2  1.08355     NaN      NaN  0.498289   5.96721      6   6.0
# 3  1.08355     NaN      NaN  0.999316  11.96720     12  12.0
# 4  1.08355     NaN      NaN  1.998630  23.93440     24  24.0
#
#             update_stamp
# 0  2020-01-09 04:20:17.0
# 1  2020-01-09 04:20:17.0
# 2  2020-03-25 15:43:58.0
# 3  2020-01-09 04:20:17.0
# 4  2020-01-09 04:20:17.0

# %%
# Column processing

# Column selection filtered by rows present in df_bl
df_col = df_adni[['RID', 'PTRACCAT']]
df_filtered = df_col.loc[df_col['RID'].isin(df_bl['RID'])]

# Drop duplicates and sort by 'RID'
df_filtered = df_filtered.drop_duplicates().sort_values(by = 'RID')

# Merge with df_bl to add ethnicity info
df_merged = df_bl.merge(df_filtered, on = 'RID', how = 'inner')

# Transform PTRACCAT to match main_data codification
ethnicity_dict = {
    'White': 'Caucasian',
    'Black': 'African American',
    'Asian': 'Asian'
}
df_merged['PTRACCAT'] = df_merged['PTRACCAT'].apply(lambda x: ethnicity_dict[x] if (x in ethnicity_dict.keys()) else 'Other')

# Rearrange columns to match main_data structure
df_adni_merged = df_merged[['RID', 'Age', 'Gender', 'PTRACCAT', 'Education_yrs', 'Smoking', 'CVD', 'Diabetes',
       'Depression', 'Hypertension', 'Stroke', 'MMSE', 'MOCA', 'APOE4',
       'DX', 'Group', 'Plasma_ptau181']]

# Final column rename to match main_data
df_adni_merged.rename(columns = {'RID': 'Patient_ID', 'PTRACCAT': 'Ethnicity'}, inplace = True)

# Transform Patient_ID to identify source dataset
df_adni_merged['Patient_ID'] = df_adni_merged['Patient_ID'].apply(lambda x: f'adni_{x}')

# %%
df_adni_merged
# Out:
#     Patient_ID   Age  Gender  Ethnicity  Education_yrs  Smoking  CVD  \
# 0    adni_2002  64.8       0  Caucasian             16      1.0  1.0
# 1    adni_2007  83.4       1  Caucasian             20      0.0  0.0
# 2    adni_2010  62.9       1      Other             20      NaN  NaN
# 3    adni_2018  76.4       1  Caucasian             18      0.0  1.0
# 4    adni_2022  66.0       0      Other             18      0.0  1.0
# ..         ...   ...     ...        ...            ...      ...  ...
# 762  adni_5289  59.7       1  Caucasian             16      NaN  NaN
# 763  adni_5290  67.0       1  Caucasian             12      0.0  1.0
# 764  adni_5292  74.3       1  Caucasian             13      0.0  0.0
# 765  adni_5295  75.5       1  Caucasian             15      NaN  NaN
# 766  adni_5296  69.3       0  Caucasian             14      0.0  1.0
#
#      Diabetes  Depression  Hypertension  Stroke  MMSE  MOCA  APOE4   DX Group  \
# 0         0.0         0.0           0.0     0.0    28  28.0      0  MCI  MCI-
# 1         1.0         0.0           1.0     0.0    29  23.0      0  MCI  MCI+
# 2         NaN         NaN           NaN     NaN    30  27.0      1  MCI  MCI+
# 3         0.0         0.0           1.0     0.0    29  26.0      0  MCI  MCI-
# 4         0.0         0.0           1.0     0.0    29  25.0      1  MCI  MCI+
# ..        ...         ...           ...     ...   ...   ...    ...  ...   ...
# 762       NaN         NaN           NaN     NaN    29  27.0      1   CU   CU-
# 763       0.0         1.0           1.0     0.0    29  25.0      1   CU   CU-
# 764       0.0         1.0           0.0     0.0    30  29.0      0   CU   CU-
# 765       NaN         NaN           NaN     NaN    29  27.0      1   CU   CU-
# 766       0.0         0.0           0.0     0.0    29  26.0      0   CU   CU-
#
#      Plasma_ptau181
# 0             6.777
# 1            37.897
# 2            23.263
# 3            10.252
# 4            16.576
# ..              ...
# 762           8.672
# 763          18.583
# 764          17.408
# 765          10.932
# 766           4.045
#
# [767 rows x 17 columns]

# %%
# Save clean dataset

df_adni_merged.to_csv('../data/processed/adni_data.csv', index = False)

# %% [markdown]
# ## Dataset Cards

# %% [markdown]
# #### Dataset main_data

# %% [markdown]
# * **Dataset**: main_data.csv
# * **Description**: This dataset contains health information for 2,149 patients, each identified with alphanumeric IDs. It includes demographic details, lifestyle factors, medical history, clinical measurements, cognitive and functional assessments, symptoms and a diagnosis of Alzheimer's Disease.
# * **Time frame**: 2024
# * **Source**: [Alzheimer's Disease Dataset](https://www.kaggle.com/dsv/8668279)
#
# </br>
#
# | Column         | Description                                | Variable type | Relevance | Notes |
# |----------------|--------------------------------------------|---------------|-----------|-------|
# | Patient_ID     | ID, 'm_' and a number sequence             | Categorical   | -         | - |
# | Age            | Age of the patient                         | Numeric       | 1         | - |
# | Gender         | Gender of the patient                      | Binary        | 3         | 0 = male, 1 = female |
# | Ethnicity      | Ethnicity of the patient                   | Categorical   | 3         | Caucasian, African American, Asian and Other |
# | Education_lv   | Highest level of formal education achieved | Categorical   | 3         | None, High School, Bachelor's, Higher |
# | BMI            | Body Mass Index of the patient             | Numeric       | 3         | - |
# | Smoking        | Smoking status                             | Binary        | 3         | 0 = no, 1 = yes |
# | Alcohol_Consumption | Weekly alcohol consumption in units   | Numeric       | 3         | Range 0-20  |
# | Physical_Activity | Weekly physical activity in hours       | Numeric       | 3         | Range 0-10  |
# | Diet_Quality   | Diet quality score                         | Numeric       | 3         | Range 0-10  |
# | Sleep_Quality  | Sleep quality score                        | Numeric       | 2         | Range 4-10  |
# | Family_History_Alzheimers | Family history of Alzheimer's Disease | Binary  | 0         | 0 = no, 1 = yes  |
# | CVD            | History of cardiovascular disease          | Binary        | 2         | 0 = no, 1 = yes |
# | Diabetes       | History of diabetes                        | Binary        | 2         | 0 = no, 1 = yes |
# | Depression     | Presence of depression                     | Binary        | 2         | 0 = no, 1 = yes |
# | Head_Injury    | History of head injury                     | Binary        | 2         | 0 = no, 1 = yes |
# | Hypertension   | Presence of hypertension                   | Binary        | 2         | 0 = no, 1 = yes |
# | Systolic_BP    | Systolic blood pressure (mmHg)             | Numeric       | 2         | - |
# | Diastolic_BP   | Diastolic blood pressure (mmHg)            | Numeric       | 2         | - |
# | Cholesterol_Total | Total cholesterol levels (mg/dL)        | Numeric       | 2         | < 200 |
# | Cholesterol_LDL | Low-density lipoprotein cholesterol levels (mg/dL)| Numeric | 2       | < 100 |
# | Cholesterol_HDL | High-density lipoprotein cholesterol levels (mg/dL)| Numeric | 2      | > 40 |
# | Cholesterol_Triglycerides | Triglycerides levels (mg/dL)    | Numeric       | 2         | < 150 |
# | MMSE           | Mini-Mental State Examination Score        | Numeric       | 0         | Range 0-30 |
# | Functional_Assessment | Functional assessment Score         | Numeric       | 1         | Range 0-10 |
# | Memory_Complaints | Subjective memory complaints            | Binary        | 0         | 0 = no, 1 = yes |
# | Behavioral_Problems | Presence of behavioral problems       | Binary        | 1         | 0 = no, 1 = yes |
# | ADL            | Activities of Daily Living Score           | Numeric       | 1         | Range 0-10 |
# | Confusion      | Presence of confusion                      | Binary        | 1         | 0 = no, 1 = yes |
# | Disorientation | Presence of disorientation                 | Binary        | 1         | 0 = no, 1 = yes |
# | Personality_Changes | Presence of personality changes       | Binary        | 1         | 0 = no, 1 = yes |
# | Difficulty_Completing_Tasks | Presence of difficulty completing tasks | Binary | 0      | 0 = no, 1 = yes |
# | Forgetfulness  | Presence of forgetfulness	              | Binary        | 0         | 0 = no, 1 = yes |
# | DX             | Diagnosis status for Alzheimer's Disease   | Binary        | 0         | 0 = no, 1 = yes|

# %%
classify_by_cardinality(df_ad)
# Out:
#                             Cardinality % Cardinality     Type  \
# Patient_ID                         2149         100.0   object
# Age                                  31      1.442531    int64
# Gender                                2      0.093067    int64
# Ethnicity                             4      0.186133   object
# Education_lv                          4      0.186133   object
# BMI                                2149         100.0  float64
# Smoking                               2      0.093067    int64
# Alcohol_Consumption                2149         100.0  float64
# Physical_Activity                  2149         100.0  float64
# Diet_Quality                       2149         100.0  float64
# Sleep_Quality                      2149         100.0  float64
# Family_History_Alzheimers             2      0.093067    int64
# CVD                                   2      0.093067    int64
# Diabetes                              2      0.093067    int64
# Depression                            2      0.093067    int64
# Head_Injury                           2      0.093067    int64
# Hypertension                          2      0.093067    int64
# Systolic_BP                          90      4.187994    int64
# Diastolic_BP                         60      2.791996    int64
# Cholesterol_Total                  2149         100.0  float64
# Cholesterol_LDL                    2149         100.0  float64
# Cholesterol_HDL                    2149         100.0  float64
# Cholesterol_Triglycerides          2149         100.0  float64
# MMSE                               2149         100.0  float64
# Functional_Assessment              2149         100.0  float64
# Memory_Complaints                     2      0.093067    int64
# Behavioral_Problems                   2      0.093067    int64
# ADL                                2149         100.0  float64
# Confusion                             2      0.093067    int64
# Disorientation                        2      0.093067    int64
# Personality_Changes                   2      0.093067    int64
# Difficulty_Completing_Tasks           2      0.093067    int64
# Forgetfulness                         2      0.093067    int64
# DX                                    2      0.093067    int64
#
#                                    Suggested Type  Possible Index
# Patient_ID                       Categorical (id)            True
# Age                            Numeric (discrete)           False
# Gender                                     Binary           False
# Ethnicity                             Categorical           False
# Education_lv                          Categorical           False
# BMI                          Numeric (continuous)           False
# Smoking                                    Binary           False
# Alcohol_Consumption          Numeric (continuous)           False
# Physical_Activity            Numeric (continuous)           False
# Diet_Quality                 Numeric (continuous)           False
# Sleep_Quality                Numeric (continuous)           False
# Family_History_Alzheimers                  Binary           False
# CVD                                        Binary           False
# Diabetes                                   Binary           False
# Depression                                 Binary           False
# Head_Injury                                Binary           False
# Hypertension                               Binary           False
# Systolic_BP                    Numeric (discrete)           False
# Diastolic_BP                   Numeric (discrete)           False
# Cholesterol_Total            Numeric (continuous)           False
# Cholesterol_LDL              Numeric (continuous)           False
# Cholesterol_HDL              Numeric (continuous)           False
# Cholesterol_Triglycerides    Numeric (continuous)           False
# MMSE                         Numeric (continuous)           False
# Functional_Assessment        Numeric (continuous)           False
# Memory_Complaints                          Binary           False
# Behavioral_Problems                        Binary           False
# ADL                          Numeric (continuous)           False
# Confusion                                  Binary           False
# Disorientation                             Binary           False
# Personality_Changes                        Binary           False
# Difficulty_Completing_Tasks                Binary           False
# Forgetfulness                              Binary           False
# DX                                         Binary           False

# %% [markdown]
# #### Dataset biomarker_data

# %% [markdown]
# * **Dataset**: biomarker_data.csv
# * **Description**: This dataset contains information for 113 patients, each identified with alphanumeric IDs. It includes relevant diagnosis, demographic details, lifestyle factors, cognitive assessments and blood marker measurements.
# * **Time frame**: unknown / 2024
# * **Source**: [Blood marker data](https://figshare.com/articles/dataset/Blood_marker_data_XLSX/26316985?file=47733910)
#
# </br>
#
# | Column         | Description                                | Variable type | Relevance | Notes |
# |----------------|--------------------------------------------|---------------|-----------|-------|
# | Patient_ID     | ID, 'bm_' and a number sequence            | Categorical   | -         | - |
# | Gender         | Gender of the patient                      | Binary        | 3         | 0 = male, 1 = female |
# | Age            | Age of the patient                         | Numeric       | 1         | - |
# | BMI            | Body Mass Index of the patient             | Numeric       | 3         | - |
# | Education_yrs  | Number of years of formal education        | Numeric       | 3         | - |
# | Smoking        | Smoking status                             | Binary        | 3         | 0 = no, 1 = yes |
# | Drinking       | Alcohol consumption status                 | Binary        | 3         | 0 = no, 1 = yes |
# | Hypertension   | History of hypertension                    | Binary        | 2         | 0 = no, 1 = yes |
# | CVD            | History of cardiovascular (coronary) disease| Binary        | 2         | 0 = no, 1 = yes |
# | Diabetes       | History of diabetes                        | Binary        | 2         | 0 = no, 1 = yes |
# | MMSE           | Mini-Mental State Examination Score        | Numeric       | 0         | Range 0-30 |
# | MOCA           | Montreal Cognitive Assessment Score        | Numeric       | 0         | Range 0-30 |
# | DX             | Neurological classification of the patient | Categorical   | 0         | CU = Cognitively Unimpaired, MCI = Mild Cognitive Impairment, AD = Alzheimer's Disease|
# | Plasma_GFAP    | GFAP plasma quantification (pg/mL)         | Numeric       | 1         | - |
# | Plasma_NfL     | NfL plasma quantification (pg/mL)          | Numeric       | 1         | - |
# | Plasma_ptau181 | P-tau181 plasma quantification (pg/mL)     | Numeric       | 0         | - |

# %%
classify_by_cardinality(df_biomarker)
# Out:
#                Cardinality % Cardinality     Type        Suggested Type  \
# Patient_ID             113         100.0   object      Categorical (id)
# Gender                   2      1.769912    int64                Binary
# Age                     38     33.628319    int64  Numeric (continuous)
# BMI                    108     95.575221  float64  Numeric (continuous)
# Education_yrs           11      9.734513    int64    Numeric (discrete)
# Smoking                  2      1.769912    int64                Binary
# Drinking                 2      1.769912    int64                Binary
# Hypertension             2      1.769912    int64                Binary
# CVD                      2      1.769912    int64                Binary
# Diabetes                 2      1.769912    int64                Binary
# MMSE                    18     15.929204    int64  Numeric (continuous)
# MOCA                    24     21.238938    int64  Numeric (continuous)
# DX                       3      2.654867   object           Categorical
# Plasma_GFAP            113         100.0  float64  Numeric (continuous)
# Plasma_NfL             112     99.115044  float64  Numeric (continuous)
# Plasma_ptau181         113         100.0  float64  Numeric (continuous)
#
#                 Possible Index
# Patient_ID                True
# Gender                   False
# Age                      False
# BMI                      False
# Education_yrs            False
# Smoking                  False
# Drinking                 False
# Hypertension             False
# CVD                      False
# Diabetes                 False
# MMSE                     False
# MOCA                     False
# DX                       False
# Plasma_GFAP              False
# Plasma_NfL               False
# Plasma_ptau181           False

# %% [markdown]
# #### Dataset adni_data

# %% [markdown]
# * **Dataset**: adni_data.csv
# * **Description**: This dataset contains health information for 767 patients, each identified with alphanumeric IDs. The dataset includes demographic details, lifestyle factors, medical history, clinical measurements, cognitive assessments, and neurological classification.
# * **Time frame**: 2010-2020
# * **Source**: [Plasma p-tau181 Level Predicts Neurodegeneration and Progression to Alzheimer's Dementia: A Longitudinal Study](https://figshare.com/articles/dataset/Data_Sheet_1_Plasma_p-tau181_Level_Predicts_Neurodegeneration_and_Progression_to_Alzheimer_s_Dementia_A_Longitudinal_Study_ZIP/16576709?file=30681404)
#
# </br>
#
# | Column         | Description                                | Variable type | Relevance | Notes |
# |----------------|--------------------------------------------|---------------|-----------|-------|
# | Patient_ID     | ID, 'adni_' and a number sequence          | Categorical   | -         | - |
# | Age            | Age of the patient                         | Numeric       | 1         | - |
# | Gender         | Gender of the patient                      | Binary        | 3         | 0 = male, 1 = female |
# | Ethnicity      | Ethnicity of the patient                   | Categorical   | 3         | Caucasian, African American, Asian and Other |
# | Education_yrs  | Number of years of formal education        | Numeric       | 3         | - |
# | Smoking        | Smoking status                             | Binary        | 3         | 0 = no, 1 = yes |
# | CVD            | History of cardiovascular disease          | Binary        | 2         | 0 = no, 1 = yes |
# | Diabetes       | History of diabetes                        | Binary        | 2         | 0 = no, 1 = yes |
# | Depression     | Current depression                         | Binary        | 2         | 0 = no, 1 = yes |
# | Hypertension   | History of hypertension                    | Binary        | 2         | 0 = no, 1 = yes |
# | Stroke         | History of a stroke                        | Binary        | 2         | 0 = no, 1 = yes |
# | MMSE           | Mini-Mental State Examination Score        | Numeric       | 0         | Range 0-30 |
# | MOCA           | Montreal Cognitive Assessment Score        | Numeric       | 0         | Range 0-30 |
# | APOE4          | Carrier of APOE4 gen                       | Categorical   | 2         | 0 = no, 1 = HT, 2 = HZ |
# | Group          | DX with specified $\beta$-amiloid (+ / -)  | Categorical   | 1         | - |
# | DX             | Neurological classification of the patient | Categorical   | 0         | CU = Cognitively Unimpaired, MCI = Mild Cognitive Impairment, AD = Alzheimer's Disease|
# | Plasma_ptau181 | P-tau181 plasma quantification (pg/mL)     | Numeric       | 0         | - |

# %%
# Timeframe specification
df = df_adni[['RID', 'EXAMDATE']]
df = df.loc[df['RID'].isin(df_bl['RID'])].sort_values(by = 'RID')
df['EXAMDATE'] = pd.to_datetime(df['EXAMDATE'])
df_unique = df.drop_duplicates(subset = 'RID', keep = 'first')
df_unique = df_unique.sort_values(by = 'EXAMDATE')
print('Beginning timeframe:', df_unique['EXAMDATE'].iloc[0])
print('End timeframe:', df_unique['EXAMDATE'].iloc[-1])
# Out:
# Beginning timeframe: 2010-07-06 00:00:00
# End timeframe: 2020-08-04 00:00:00

# %%
classify_by_cardinality(df_adni_merged)
# Out:
#                Cardinality % Cardinality     Type        Suggested Type  \
# Patient_ID             767         100.0   object      Categorical (id)
# Age                    266     34.680574  float64  Numeric (continuous)
# Gender                   2      0.260756    int64                Binary
# Ethnicity                4      0.521512   object           Categorical
# Education_yrs           13      1.694915    int64    Numeric (discrete)
# Smoking                  2      0.260756  float64                Binary
# CVD                      2      0.260756  float64                Binary
# Diabetes                 2      0.260756  float64                Binary
# Depression               2      0.260756  float64                Binary
# Hypertension             2      0.260756  float64                Binary
# Stroke                   2      0.260756  float64                Binary
# MMSE                    12      1.564537    int64    Numeric (discrete)
# MOCA                    25      3.259452  float64    Numeric (discrete)
# APOE4                    3      0.391134    int64           Categorical
# DX                       3      0.391134   object           Categorical
# Group                    5       0.65189   object           Categorical
# Plasma_ptau181         765     99.739244  float64  Numeric (continuous)
#
#                 Possible Index
# Patient_ID                True
# Age                      False
# Gender                   False
# Ethnicity                False
# Education_yrs            False
# Smoking                  False
# CVD                      False
# Diabetes                 False
# Depression               False
# Hypertension             False
# Stroke                   False
# MMSE                     False
# MOCA                     False
# APOE4                    False
# DX                       False
# Group                    False
# Plasma_ptau181           False
